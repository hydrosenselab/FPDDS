# %%
## Data handlers
from dask_jobqueue import *
from dask.distributed import *
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import netCDF4 
from dask import delayed
from dask import compute
from dask.diagnostics import*
from tqdm import tqdm
import dask
## Plots
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.mlab as mlab
import matplotlib.colors as mcl
from mpl_toolkits import axes_grid1
import seaborn as sns
import matplotlib.dates as mdates
import geopandas
import rioxarray
from shapely.geometry import mapping
## Global config
import os, sys, glob
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import config 
import gc
import warnings
warnings.filterwarnings('ignore')

# %%
#Open LSM output file and GRACE file at monthly timestep for India
lsm_r =  xr.open_dataset("/home/civil/phd/cez218606/LISF1/Results/MERRA2/lsm_monthly/lsm_monthly.nc")
grun_r = xr.open_dataset("/home/civil/phd/cez218606/LISF1/Results/IMDAA/Grun_runoff_monthly/grun_monthly_regrid.nc")
lsm_r = lsm_r.assign(total_runoff = (lsm_r['Qs_tavg']*86400))
#grun_r = grace_m.assign(tws = (grace_m['lwe_thickness'])*(10)) # Convert TWSA to mm in Grace dataset.

# %%
# Downscale GRACE by a factor of 3 and slice for 10 years data 
#new_lon = np.linspace(grun_r.X[0], grun_r.X[-1], grun_r.dims["X"] * 3)
#new_lat = np.linspace(grun_r.Y[0], grun_r.Y[-1], grun_r.dims["Y"] * 3)
#grun_r = grun_r.interp(Y=new_lat, X=new_lon)
grun_r = grun_r.sel(time=slice("2009-01-01", "2014-12-31"))
grun_r  = grun_r.resample(time='1M').mean()

# %%
# Calculate TWS Anomalies in LSM dataset
#climatology = lsm_m.mean('time')
#anomalies = lsm_m- climatology
lsm_r
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 72, lat: 303, lon: 292, SoilMoist_profiles: 4)
# Coordinates:
#   * time              (time) datetime64[ns] 2009-01-31 2009-02-28 ... 2014-12-31
#   * lat               (lat) float64 6.85 6.95 7.05 7.15 ... 36.85 36.95 37.05
#   * lon               (lon) float64 68.25 68.35 68.45 ... 97.15 97.25 97.35
#     spatial_ref       int64 ...
# Dimensions without coordinates: SoilMoist_profiles
# Data variables: (12/18)
#     Swnet_tavg        (time, lat, lon) float32 ...
#     Lwnet_tavg        (time, lat, lon) float32 ...
#     Qle_tavg          (time, lat, lon) float32 ...
#     Qh_tavg           (time, lat, lon) float32 ...
#     Qg_tavg           (time, lat, lon) float32 ...
#     Snowf_tavg        (time, lat, lon) float32 ...
#     ...                ...
#     SoilMoist_tavg    (time, SoilMoist_profiles, lat, lon) float32 ...
#     WaterTableD_tavg  (time, lat, lon) float32 ...
#     TWS_tavg          (time, lat, lon) float32 ...
# ...

# %%
#Compare time-series of GRACE vs LSM TWSA at a given lat/lon
fig = plt.subplots(1, 1, figsize=(8,4),dpi = 120,constrained_layout=False )
#grun_r['Runoff'].sel(lat=35, lon=79, method='nearest').plot(label='GRUN')
lsm_r['total_runoff'].sel(lat=35, lon=79, method='nearest').plot(label='LSM')
plt.legend()
plt.title('GRUN vs LSM (MERRA2) Total Runoff at 22N 78E')
plt.ylabel('Runoff (mm)')
#plt.savefig('/home/civil/phd/cez218606/LISF1/Results/MERRA2/images/GRUN_vs_LSM_MERRA2.png',format = 'png', dpi=300)
# Out:
# Text(0, 0.5, 'Runoff (mm)')

# %%
#Compare time-series of GRACE vs LSM TWSA at a given lat/lon
fig = plt.subplots(1, 1, figsize=(8,4),dpi = 120,constrained_layout=False )
grun_r['Runoff'].sel(lat=19, lon=78, method='nearest').plot(label='GRUN')
lsm_r['total_runoff'].sel(lat=19, lon=78, method='nearest').plot(label='LSM')
plt.legend()
plt.title('GRUN vs LSM (MERRA2) Total Runoff at 19N 78E')
plt.ylabel('Runoff (mm)')
#plt.savefig('/home/civil/phd/cez218606/LISF1/Results/MERRA2/images/GRUN_vs_LSM_MERRA21.png',format = 'png', dpi=300)
# Out:
# Text(0, 0.5, 'Runoff (mm)')

# %%
# Compare Spatial Distribution of GRACE vs LSM TWSA for a given month (2004-09-30)
fig, axes= plt.subplots(1, 2, figsize=(12,8),dpi = 120,constrained_layout=False )

font_size = 10
plt.style.use('seaborn-white')
for i, ax in enumerate(axes.flatten()):
    
    if i == 0 :
        im=xr.plot.imshow(lsm_r['total_runoff'].isel(time=71), 
                          cmap="jet_r",add_colorbar=False,ax=ax)
        ax.set_title('LSM MERRA2 Runoff (mm) for 2009-01-01',size = 9,loc='left')
        ax.set_title("",size = 9)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel('')
        ax.set_xlabel('')
        divider = axes_grid1.make_axes_locatable(ax)
        cax = divider.append_axes('right', size='5%', pad=0.05)
        cbar = fig.colorbar(im, cax=cax)
    if  i==1 :
        im=xr.plot.imshow(grun_r['Runoff'].isel(time=71), 
                          cmap="jet_r",add_colorbar=False,ax=ax)
        ax.set_title('GRUN Runoff (mm) for 2009-01-01',size = 9,loc='left')
        ax.set_title("",size = 9)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel('')
        ax.set_xlabel('')
        divider = axes_grid1.make_axes_locatable(ax)
        cax = divider.append_axes('right', size='5%', pad=0.05)
        cbar = fig.colorbar(im, cax=cax)
#plt.savefig('/home/civil/phd/cez218606/LISF1/Results/MERRA2/images/LSM_MERRA2_Runoff_2009-01-01.png',format = 'png', dpi=300)
#plt.close()

# %%
# Group by monthly means for TWSA and plot to compare spatial distribution for a single year
grace_month = grun_r.groupby("time.month").mean()
anomalies_month = lsm_r.groupby("time.month").mean()


months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
for j in range (0,12):
    fig, axes= plt.subplots(1, 2, figsize=(12,8),dpi = 120,constrained_layout=False )

    font_size = 10
    plt.style.use('seaborn-white')
    for i, ax in enumerate(axes.flatten()):
        if i == 0 :
            im=xr.plot.imshow(anomalies_month['total_runoff'].isel(month=j), 
                            cmap="jet_r",add_colorbar=False,ax=ax)
            ax.set_title('Mean LSM MERRA2 Runoff (mm) for '+months[j]+' (2004-2014)',size = 9,loc='left')
            ax.set_title("",size = 9)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_ylabel('')
            ax.set_xlabel('')
            divider = axes_grid1.make_axes_locatable(ax)
            cax = divider.append_axes('right', size='5%', pad=0.05)
            cbar = fig.colorbar(im, cax=cax)
        if  i==1 :
            im=xr.plot.imshow(grace_month['Runoff'].isel(month=j), 
                            cmap="jet_r",add_colorbar=False,ax=ax)
            ax.set_title('GRUN Runoff (mm) for '+months[j]+' (2004-2014)',size = 9,loc='left')
            ax.set_title("",size = 9)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_ylabel('')
            ax.set_xlabel('')
            divider = axes_grid1.make_axes_locatable(ax)
            cax = divider.append_axes('right', size='5%', pad=0.05)
            cbar = fig.colorbar(im, cax=cax)     
   # plt.savefig('/home/civil/phd/cez218606/LISF1/Results/MERRA2/images/'+str(j)+'.png',format = 'png', dpi=300)
   # plt.close()

# %%
# Generate Annual mean for TWSA and plot to compare spatial distribution for 2004-2014
grace_mean = grace_month.mean(dim='month')
anomalies_mean = anomalies_month.mean(dim='month')
fig, axes= plt.subplots(1, 2, figsize=(12,8),dpi = 120,constrained_layout=False )

font_size = 10
plt.style.use('seaborn-white')
for i, ax in enumerate(axes.flatten()):
    
    if i == 0 :
        im=xr.plot.imshow(anomalies_mean['total_runoff'], 
                          cmap="jet",add_colorbar=False,ax=ax)
        ax.set_title('Annual Mean LSM MERRA2 Runoff (mm) for 2009-2014',size = 9,loc='left')
        ax.set_title("",size = 9)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel('')
        ax.set_xlabel('')
        divider = axes_grid1.make_axes_locatable(ax)
        cax = divider.append_axes('right', size='5%', pad=0.05)
        cbar = fig.colorbar(im, cax=cax)
    if  i==1 :
        im=xr.plot.imshow(grace_mean['Runoff'], 
                          cmap="jet",add_colorbar=False,ax=ax)
        ax.set_title('Annual Mean GRUN Runoff (mm) for 2009-2014',size = 9,loc='left')
        ax.set_title("",size = 9)
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylabel('')
        ax.set_xlabel('')
        divider = axes_grid1.make_axes_locatable(ax)
        cax = divider.append_axes('right', size='5%', pad=0.05)
        cbar = fig.colorbar(im, cax=cax)
#plt.savefig('/home/civil/phd/cez218606/LISF1/Results/MERRA2/images/Annual_MeanLSM_MERRA2_Runoff.png',format = 'png', dpi=300)
#plt.close()

# %%
grace_mean
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 292, lat: 303)
# Coordinates:
#   * lon      (lon) float64 68.25 68.35 68.45 68.55 ... 97.05 97.15 97.25 97.35
#   * lat      (lat) float64 6.85 6.95 7.05 7.15 7.25 ... 36.75 36.85 36.95 37.05
# Data variables:
#     Runoff   (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
def covariance(x, y, dims=None):
    return xr.dot(x - x.mean(dims), y - y.mean(dims), dims=dims) / x.count(dims)

def corrrelation(x, y, dims=None):
    return covariance(x, y, dims) / (x.std(dims) * y.std(dims))

def rmse(x, y, dims=None):
    return np.sqrt(((x - y) ** 2).mean(dims))

def bias(x, y, dims=None):
    return ((x - y).mean(dims))


def KGE(x, y, dims=None):
    return  (1- np.sqrt((1-corrrelation(x, y, dims))**2 + (1-(x.mean(dims)/y.mean(dims)))**2 + (1-(x.std(dims)/y.std(dims)))**2))

# %%
lsmr = lsm_r.total_runoff
grunr = grun_r['Runoff']

# %%
sst_kge = KGE(lsmr, grunr, dims='time')
pc = sst_kge.plot()
pc.axes.set_title('KGE btw. LSM MERRA2 Runoff and GRUN Runoff')
# Out:
# Text(0.5, 1.0, 'KGE btw. LSM MERRA2 Runoff and GRUN Runoff')

# %%
sst_kge.median()
# Out:
# <xarray.DataArray ()>
# array(0.39507333)
# Coordinates:
#     spatial_ref  int64 0

# %%
sst_cor = corrrelation(lsmr, grunr, dims='time')
pc = sst_cor.plot()
#pc = xr.plot.imshow(sst_cor,cmap="jet",add_colorbar=False,ax=ax)
pc.axes.set_title('Correlation btw. LSM MERRA2 Runoff and GRUN Runoff')
# Out:
# Text(0.5, 1.0, 'Correlation btw. LSM MERRA2 Runoff and GRUN Runoff')

# %%
sst_cor.median()
# Out:
# <xarray.DataArray ()>
# array(0.88155011)
# Coordinates:
#     spatial_ref  int64 0

# %%
#sst_cor.to_netcdf('/home/civil/phd/cez218606/LISF1/Results/MERRA2/error/MERRA2_runoff_corr.nc')

# %%
#from math import sqrt
sst_rmse = rmse(lsmr, grunr, dims='time')
pc = sst_rmse.plot()

# %%
sst_rmse.median()
# Out:
# <xarray.DataArray ()>
# array(0.46368373)
# Coordinates:
#     spatial_ref  int64 0

# %%
#sst_rmse.to_netcdf('/home/civil/phd/cez218606/LISF1/Results/MERRA2/error/MERRA2_runoff_rmse.nc')

# %%
sst_bias = bias(lsmr, grunr, dims='time')
pc = sst_bias.plot()

# %%
sst_bias.median()
# Out:
# <xarray.DataArray ()>
# array(-0.16516542)
# Coordinates:
#     spatial_ref  int64 0

# %%
#sst_bias.to_netcdf('/home/civil/phd/cez218606/LISF1/Results/MERRA2/error/MERRA2_runoff_bias.nc')

# %%
sst_kge['kge'] =sst_kge 
sst_kge['cor'] =sst_cor
sst_kge['rmse'] =sst_rmse
sst_kge['bias'] =sst_bias

# %%
sst_kge
# Out:
# <xarray.DataArray (lat: 303, lon: 292)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * lat          (lat) float64 6.85 6.95 7.05 7.15 ... 36.75 36.85 36.95 37.05
#   * lon          (lon) float64 68.25 68.35 68.45 68.55 ... 97.15 97.25 97.35
#     spatial_ref  int64 0
#     kge          (lat, lon) float64 nan nan nan nan nan ... nan nan nan nan nan
#     cor          (lat, lon) float64 nan nan nan nan nan ... nan nan nan nan nan
#     rmse         (lat, lon) float64 nan nan nan nan nan ... nan nan nan nan nan
#     bias         (lat, lon) float64 nan nan nan nan nan ... nan nan nan nan nan

# %%
sst_kge.to_netcdf('/home/civil/phd/cez218606/LISF1/Results/MERRA2/error/MERRA2_runoff_error_matrix.nc')
