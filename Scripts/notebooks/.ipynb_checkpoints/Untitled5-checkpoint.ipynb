# %%
#!/usr/bin/env python
# coding: utf-8

# In[9]:


## Data handlers
from dask_jobqueue import *
from dask.distributed import *
import xarray as xr
import numpy as np
import pandas as pd
import datetime
import netCDF4 
from dask import delayed
from dask import compute
from dask.diagnostics import*
from tqdm import tqdm
import dask


## Global config
import os, sys, glob
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import config 
import gc
import warnings
warnings.filterwarnings('ignore')

error_files = []
for file in sorted(glob.glob('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/output/error_metrix/*')) :
    error_files.append(file)

for i in range(0,len(error_files)):
    #parameter update   
        colnames=['a','b','c','d','e','f','g','h','i','j','k','l']
        colnames1=['a']
        soil_param_new = pd.read_csv('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/SOILPARM.TBL',names=colnames,sep = ", ")
        soil_param_old = pd.read_csv('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/best_parm/SOILPARM_NEW.TBL',names=colnames,sep = ", ")
        gen_param = pd.read_csv('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/GENPARM_NEW.TBL',names=colnames1,sep = ",")
        #new
        BB_new=(soil_param_new['b'][3])
        MAXSMC_new=(soil_param_new['e'][3])
        REFSMC_new=(soil_param_new['f'][3])
        SATDK_new=(soil_param_new['h'][3])
        #privious
        BB_old=(soil_param_old['b'][3])
        MAXSMC_old=(soil_param_old['e'][3])
        REFSMC_old=(soil_param_old['f'][3])
        SATDK_old=(soil_param_old['h'][3])
        #multiplair
        BB_mult = BB_new/BB_old
        MAXSMC_mult = MAXSMC_new/MAXSMC_old
        REFSMC_mult = REFSMC_new/REFSMC_old
        SATDK_mult =SATDK_new/SATDK_old
        #all
        BB=(soil_param_old['b'][3:14]).values
        MAXSMC=(soil_param_old['e'][3:14]).values
        REFSMC=(soil_param_old['f'][3:14]).values
        SATDK=(soil_param_old['h'][3:14]).values
        #best
        BB_best = (BB*BB_mult)
        MAXSMC_best = MAXSMC*MAXSMC_mult
        REFSMC_best = REFSMC*REFSMC_mult
        SATDK_best = SATDK*SATDK_mult

        BBn=(soil_param_old['b'][25:36]).values
        MAXSMCn=(soil_param_old['e'][25:36]).values
        REFSMCn=(soil_param_old['f'][25:36]).values
        SATDKn=(soil_param_old['h'][25:36]).values


        BB_bestn = (BBn*BB_mult)
        MAXSMC_bestn = MAXSMCn*MAXSMC_mult
        REFSMC_bestn = REFSMCn*REFSMC_mult
        SATDK_bestn = SATDKn*SATDK_mult

        
        
        with open('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/best_parm/SOILPARM_NEW.TBL', 'r', encoding='utf-8') as file:
            data = file.readlines()

        mm1 = data[3].split();mm2 = data[4].split();mm3 = data[5].split();mm4 = data[6].split();mm5 = data[7].split()
        mm6 = data[8].split();mm7 = data[9].split();mm8 = data[10].split();mm9 = data[11].split();mm10 = data[12].split()
        mm11 = data[13].split()
        mmn1 = data[25].split();mmn2 =data[26].split();mmn3 = data[27].split();mmn4 = data[28].split()
        mmn5 = data[29].split();mmn6 = data[30].split();mmn7 = data[31].split();mmn8 = data[32].split();mmn9 = data[33].split()
        mmn10 = data[34].split();mmn11 = data[35].split()
    
    
    
        oString1 = f'{mm1[0]}    {BB_new},    {mm1[2]}    {mm1[3]}    {MAXSMC_new},    {REFSMC_new},    {mm1[6]}    {SATDK_new},    {mm1[8]}    {mm1[9]}    {mm1[10]}    {mm1[11]}\n' 
        oString2 = f'{mm2[0]}    {BB_best[1]},    {mm2[2]}    {mm2[3]}    {MAXSMC_best[1]},    {REFSMC_best[1]},    {mm2[6]}    {SATDK_best[1]},    {mm2[8]}    {mm2[9]}    {mm2[10]}    {mm2[11]} {mm2[12]}\n' 
        oString3 = f'{mm3[0]}    {BB_best[2]},    {mm3[2]}    {mm3[3]}    {MAXSMC_best[2]},    {REFSMC_best[2]},    {mm3[6]}    {SATDK_best[2]},    {mm3[8]}    {mm3[9]}    {mm3[10]}    {mm3[11]} {mm3[12]}\n' 
        oString4 = f'{mm4[0]}    {BB_best[3]},    {mm4[2]}    {mm4[3]}    {MAXSMC_best[3]},    {REFSMC_best[3]},    {mm4[6]}    {SATDK_best[3]},    {mm4[8]}    {mm4[9]}    {mm4[10]}    {mm4[11]} {mm4[12]}\n' 
        oString5 = f'{mm5[0]}    {BB_best[4]},    {mm5[2]}    {mm5[3]}    {MAXSMC_best[4]},    {REFSMC_best[4]},    {mm5[6]}    {SATDK_best[4]},    {mm5[8]}    {mm5[9]}    {mm5[10]}    {mm5[11]}\n' 
        oString6 = f'{mm6[0]}    {BB_best[5]},    {mm6[2]}    {mm6[3]}    {MAXSMC_best[5]},    {REFSMC_best[5]},    {mm6[6]}    {SATDK_best[5]},    {mm6[8]}    {mm6[9]}    {mm6[10]}    {mm6[11]}\n' 
        oString7 = f'{mm7[0]}    {BB_best[6]},    {mm7[2]}    {mm7[3]}    {MAXSMC_best[6]},    {REFSMC_best[6]},    {mm7[6]}    {SATDK_best[6]},    {mm7[8]}    {mm7[9]}    {mm7[10]}    {mm7[11]} {mm7[12]} {mm7[13]}\n' 
        oString8 = f'{mm8[0]}    {BB_best[7]},    {mm8[2]}    {mm8[3]}    {MAXSMC_best[7]},    {REFSMC_best[7]},    {mm8[6]}    {SATDK_best[7]},    {mm8[8]}    {mm8[9]}    {mm8[10]}    {mm8[11]} {mm8[12]} {mm8[13]}\n' 
        oString9 = f'{mm9[0]}    {BB_best[8]},    {mm9[2]}    {mm9[3]}    {MAXSMC_best[8]},    {REFSMC_best[8]},    {mm9[6]}    {SATDK_best[8]},    {mm9[8]}    {mm9[9]}    {mm9[10]}    {mm9[11]} {mm9[12]}\n' 
        oString10 = f'{mm10[0]}    {BB_best[9]},    {mm10[2]}    {mm10[3]}    {MAXSMC_best[9]},    {REFSMC_best[9]},    {mm10[6]}    {SATDK_best[9]},    {mm10[8]}    {mm10[9]}    {mm10[10]}    {mm10[11]} {mm10[12]}\n'  
        oString11 = f'{mm11[0]}    {BB_best[10]},    {mm11[2]}    {mm11[3]}    {MAXSMC_best[10]},    {REFSMC_best[10]},    {mm11[6]}    {SATDK_best[10]},    {mm11[8]}    {mm11[9]}    {mm11[10]}    {mm11[11]} {mm11[12]}\n'  
 
        oStringn1 = f'{mmn2[0]}    {BB_bestn[0]},    {mmn2[2]}    {mmn2[3]}    {MAXSMC_bestn[0]},    {REFSMC_bestn[0]},    {mmn2[6]}    {SATDK_bestn[0]},    {mmn2[8]}    {mmn2[9]}    {mmn2[10]}    {mmn2[11]}\n' 
        oStringn2 = f'{mmn2[0]}    {BB_bestn[1]},    {mmn2[2]}    {mmn2[3]}    {MAXSMC_bestn[1]},    {REFSMC_bestn[1]},    {mmn2[6]}    {SATDK_bestn[1]},    {mmn2[8]}    {mmn2[9]}    {mmn2[10]}    {mmn2[11]} {mmn2[12]}\n' 
        oStringn3 = f'{mmn3[0]}    {BB_bestn[2]},    {mmn3[2]}    {mmn3[3]}    {MAXSMC_bestn[2]},    {REFSMC_bestn[2]},    {mmn3[6]}    {SATDK_bestn[2]},    {mmn3[8]}    {mmn3[9]}    {mmn3[10]}    {mmn3[11]} {mmn3[12]}\n' 
        oStringn4 = f'{mmn4[0]}    {BB_bestn[3]},    {mmn4[2]}    {mmn4[3]}    {MAXSMC_bestn[3]},    {REFSMC_bestn[3]},    {mmn4[6]}    {SATDK_bestn[3]},    {mmn4[8]}    {mmn4[9]}    {mmn4[10]}    {mmn4[11]} {mmn4[12]}\n' 
        oStringn5 = f'{mmn5[0]}    {BB_bestn[4]},    {mmn5[2]}    {mmn5[3]}    {MAXSMC_bestn[4]},    {REFSMC_bestn[4]},    {mmn5[6]}    {SATDK_bestn[4]},    {mmn5[8]}    {mmn5[9]}    {mmn5[10]}    {mmn5[11]}\n' 
        oStringn6 = f'{mmn6[0]}    {BB_bestn[5]},    {mmn6[2]}    {mmn6[3]}    {MAXSMC_bestn[5]},    {REFSMC_bestn[5]},    {mmn6[6]}    {SATDK_bestn[5]},    {mmn6[8]}    {mmn6[9]}    {mmn6[10]}    {mmn6[11]}\n' 
        oStringn7 = f'{mmn7[0]}    {BB_bestn[6]},    {mmn7[2]}    {mmn7[3]}    {MAXSMC_bestn[6]},    {REFSMC_bestn[6]},    {mmn7[6]}    {SATDK_bestn[6]},    {mmn7[8]}    {mmn7[9]}    {mmn7[10]}    {mmn7[11]} {mmn7[12]} {mmn7[13]}\n' 
        oStringn8 = f'{mmn8[0]}    {BB_bestn[7]},    {mmn8[2]}    {mmn8[3]}    {MAXSMC_bestn[7]},    {REFSMC_bestn[7]},    {mmn8[6]}    {SATDK_bestn[7]},    {mmn8[8]}    {mmn8[9]}    {mmn8[10]}    {mmn8[11]} {mmn8[12]} {mmn8[13]}\n' 
        oStringn9 = f'{mmn9[0]}    {BB_bestn[8]},    {mmn9[2]}    {mmn9[3]}    {MAXSMC_bestn[8]},    {REFSMC_bestn[8]},    {mmn9[6]}    {SATDK_bestn[8]},    {mmn9[8]}    {mmn9[9]}    {mmn9[10]}    {mmn9[11]} {mmn9[12]}\n' 
        oStringn10 = f'{mmn10[0]}    {BB_bestn[9]},    {mmn10[2]}    {mmn10[3]}    {MAXSMC_bestn[9]},    {REFSMC_bestn[9]},    {mmn10[6]}    {SATDK_bestn[9]},    {mmn10[8]}    {mmn10[9]}    {mmn10[10]}    {mmn10[11]} {mmn10[12]}\n'  
        oStringn11 = f'{mmn11[0]}    {BB_bestn[10]},    {mmn11[2]}    {mmn11[3]}    {MAXSMC_bestn[10]},    {REFSMC_bestn[10]},    {mmn11[6]}    {SATDK_bestn[10]},    {mmn11[8]}    {mmn11[9]}    {mmn11[10]}    {mmn11[11]} {mmn11[12]}\n'  
  
        
        
        
        
        
        
        
        
        data[3] = oString1;data[4] = oString2;data[5] = oString3;data[6] = oString4;data[7] = oString5;data[8] = oString6
        data[9] = oString7;data[10] = oString8;data[11] = oString9;data[12] = oString10;data[13] = oString11
 
        data[25] = oStringn1;data[26] = oStringn2;data[27] = oStringn3;data[28] = oStringn4;data[29] = oStringn5;data[30] = oStringn6
        data[31] = oStringn7;data[32] = oStringn8;data[33] = oStringn9;data[34] = oStringn10;data[35] = oStringn11
        
        
        
        

        with open('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/SOILPARM_NEW.TBL', 'w') as file:
            file.writelines(data)         
        with open('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/GENPARM.TBL', 'r', encoding='utf-8') as file:
            data1 = file.readlines()     
        with open('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/GENPARM.TBL', 'r', encoding='utf-8') as file:
            data2 = file.readlines() 
        (data2[21])=(data1[21])
        (data2[23])=(data1[23])       
        with open('/home/civil/phd/cez218606/Auto_calibration/Runs/PDDS_IMD/NoahMP_InputFiles/mod'+str(i)+'/GENPARM_NEW.TBL', 'w') as file:
            file.writelines(data2)        


# In[ ]:
